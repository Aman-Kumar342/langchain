# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman-Kumar342/langchain/blob/main/magicMethidInPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# magic methods in python also known as dunder methds (double underscore methods)
#,are special mrthods that start and end with double underscore . these methods
# enable you to define the behaviour of objects for built in operation such as
#arithematic operations, comparision and more

# %%
# magic methids are predefined methods in python that you can override to
# change the behaviour of your objects. some common magic methods include

# 1> init: initlize a new instance of a class
# 2> str : returns a string epresentation of an object.
#3> repr : returns an official string representation of an object
#4> len : returns the length of an object
#5> getitem : Gets an item from a container

# %%
class Person:
  def __init__(self,name,age):
    self.name=name
    self.age=age

  def __str__(self):
    return f"{self.name},{self.age,years}"
person=Person("Aman",25)
print(person)
