# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman-Kumar342/langchain/blob/main/EceptionHandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#eception handling

# exeption handling in python allow you to handle error gracefully and take corrective action without stopping the execution of the program . this will cover the basics of eception including how to use try except else and finally blocks #

# what are eception
# actually exception are event that disrupt the normal low of a program . they occur when an error is encounterd during program exection . common exception inlude:
# zeroDivisionError: Dividing by Zero,
# FileNotFoundError:File not found.
#ValueError: Invalid value

# %%
try:
  a=b
except:
  print("variable not defined")

# %%
try:
  result=1/0
except ZeroDivisionError:
  print("cannot divide by zero")

# %%
try:
  result=1/2
  a=b
except ZeroDivisionError as ex:
    print(ex)
except Exception as ex1:
  print(ex1)
  print('Main exeption')
# Out:
# name 'b' is not defined
# Main exeption

# %%
try:
  num=int(input("Enter a number"))
  res=10/num
except ValueError:
  print("This is not a valid number")
except ZeroDivisionError:
  print("enter denominator greater than 0")

# %%
try:
  num=int(input("Enter a number: "))
  resut=10/num
except ValueError:
  print("That is not a valid number")
except ZeroDivisionError:
  print("cant divide by zero")
except Exception as ex:
  print(ex)
else:
  print(f"the result is {resut}")
# Out:
# Enter a number: 4
# the result is 2.5

# %%
# try, except,else and finally

try:
  num=int(input("Enter a number: "))
  resut=10/num
except ValueError:
  print("That is not a valid number")
except ZeroDivisionError:
  print("cant divide by zero")
except Exception as ex:
  print(ex)
else:
  print(f"the result is {resut}")
finally:
  print("Exection completed")
# Out:
# Enter a number: 5
# the result is 2.0
# Exection completed

# %%
# file handling and Exception handling

try:
  file=open('example.txt','r')
  content=file.read()
  print(content)
except FileNotFoundError:
  print("this file does not exists")
finally:
  if 'file' in locals() and not file.closed():
    file.close()
    print('file close')
