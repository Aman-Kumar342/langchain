# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman-Kumar342/langchain/blob/main/Iterator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Iterator are advanced python concepts that allow for efficient looping and
#memory management . itertors provide a way to access elements of a collection
# sequentially without exposing the underlyint structure

# %%
my_list=[1,2,3,4,5,6]
for i in my_list:
  print (i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
type(my_list)
# Out:
# list

# %%
print(my_list)

# %%
#iterator
iterator=iter(my_list)
print(type(iterator))
# Out:
# <class 'list_iterator'>

# %%
iterator

# %%
next(iterator)
# Out:
# 2

# %%
iterator=iter(my_list)

# %%
try:
 print(next(iterator))
except StopIteration:
  print("There are no element in the iterator")
# Out:
# There are no element in the iterator
