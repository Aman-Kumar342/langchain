# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman-Kumar342/langchain/blob/main/Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Generator are a simpler way to create iterators. they use the yield keyword
#to produce a series of values lazily which means they generate values on the
#fly and do not store them in memory

# %%
def square(n):
  for i in range(3):
    return i**2
